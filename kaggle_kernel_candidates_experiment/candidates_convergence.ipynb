# %%
import subprocess, sys
r = subprocess.run([sys.executable, '-m', 'pip', 'install', '-q', 'craftax', 'optax'], capture_output=True, text=True)
print(r.stdout[-1500:], r.stderr[-1500:] if r.returncode else '')
import jax; print('JAX Backend:', jax.default_backend(), jax.devices(), jax.__version__)

# %%
import base64, os
os.makedirs('src', exist_ok=True)
with open('src/__init__.py', 'w') as _f: _f.write('')
os.makedirs('src/__pycache__', exist_ok=True)
os.makedirs('src/environment', exist_ok=True)
os.makedirs('src/model', exist_ok=True)
os.makedirs('src/pipeline', exist_ok=True)
with open('src/__init__.py', 'wb') as _f:
    _f.write(base64.b64decode(''))
with open('src/main.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
os.makedirs('src/environment/__pycache__', exist_ok=True)
with open('src/environment/craftax_env_adapter.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/environment/craftax_obs_adapter.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/environment/gymnax_decision_env.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
os.makedirs('src/model/__pycache__', exist_ok=True)
os.makedirs('src/model/candidates', exist_ok=True)
with open('src/model/baseline_model.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/beam_search.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/channel_encoder.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/checkpoint.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/hierarchical_transformer.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/logger_utils.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/transformer_decision_core.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/types.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
os.makedirs('src/model/candidates/__pycache__', exist_ok=True)
with open('src/model/candidates/__init__.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/mdp_branch.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/passive_world_model.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/shared_stages.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/transformer_branch.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/variant_5_1_shared_attention.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/variant_5_2_channel_split.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/variant_5_3_channel_split_v2.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/variant_5_4_single_shot.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/model/candidates/world_model.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
os.makedirs('src/pipeline/__pycache__', exist_ok=True)
with open('src/pipeline/benchmark.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/candidate_benchmark.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/candidate_experiment.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/craftax_benchmark.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/evaluator.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/grid_search_benchmark.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/hierarchical_pipeline.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/off_policy_trainer.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/plotter.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))
with open('src/pipeline/trainer.py', 'wb') as _f:
    _f.write(base64.b64decode('...'))

# %%
import os
os.makedirs('scripts', exist_ok=True)
import base64, os
os.makedirs('output/experiments/2026-09-25_idea6/stageA', exist_ok=True)
open('output/experiments/2026-09-25_idea6/stageA/wm_hn.pkl','wb').write(base64.b64decode('...'))
os.makedirs('output/experiments/2026-09-25_idea6/stageA', exist_ok=True)
open('output/experiments/2026-09-25_idea6/stageA/wm_mlp.pkl','wb').write(base64.b64decode('...'))
open('scripts/run_idea6_policy.py','w',encoding='utf-8').write('"""Stage B of the Idea-6 study: does a frozen, trained noop-world-model help the action-selecting Transformer?\n\nArms (identical model/adapter/training; only the 8 \'anticipation\' state features differ):\n  base           : anticipation features = zeros\n  wm_hn          : trained port-Hamiltonian world model (Stage A)\n  wm_mlp         : trained MLP world model (Stage A)\n  wm_hn_untrained: same HN architecture, random init (control: extra features with no learned content)\n"""\nimport argparse, os, pickle, sys\nsys.path.insert(0, ".")\nimport jax, jax.numpy as jnp\nfrom src.environment.craftax_obs_adapter import CraftaxObsAdapter\nfrom src.model.candidates import passive_world_model as pwm\nfrom src.pipeline.candidate_experiment import run_experiment\n\n\ndef make_adapter(arm, wm_dir, T, feat_dim=39):\n    if arm == "base":\n        return CraftaxObsAdapter(T, None, 8)\n    kind = "mlp" if arm == "wm_mlp" else "hn"\n    if arm == "wm_hn_untrained":\n        params = pwm.init_params(jax.random.PRNGKey(123), "hn", feat_dim)\n        tr = pickle.load(open(f"{wm_dir}/wm_hn.pkl", "rb"))  # borrow only the input standardisation stats\n        params["enc"]["mu"], params["enc"]["sd"] = jnp.asarray(tr["enc"]["mu"]), jnp.asarray(tr["enc"]["sd"])\n    else:\n        params = jax.tree_util.tree_map(jnp.asarray, pickle.load(open(f"{wm_dir}/wm_{kind}.pkl", "rb")))\n    return CraftaxObsAdapter(T, lambda f: pwm.anticipation_features(params, kind, f), 8)\n\n\nif __name__ == "__main__":\n    ap = argparse.ArgumentParser()\n    ap.add_argument("--out", required=True); ap.add_argument("--wm-dir", required=True)\n    ap.add_argument("--arms", nargs="+", required=True); ap.add_argument("--seeds", nargs="+", type=int, default=[0])\n    ap.add_argument("--candidate", default="transformer_branch")\n    ap.add_argument("--updates", type=int, default=250); ap.add_argument("--batch", type=int, default=16)\n    ap.add_argument("--T", type=int, default=250); ap.add_argument("--d-model", type=int, default=256)\n    a = ap.parse_args()\n    print("backend", jax.default_backend(), flush=True)\n    for seed in a.seeds:\n        for arm in a.arms:\n            ad = make_adapter(arm, a.wm_dir, a.T)\n            run_experiment(a.candidate, a.out, updates=a.updates, batch=a.batch, T=a.T, d_model=a.d_model,\n                           mode="reinforce", eval_every=50, eval_eps=32, seed=seed, adapter=ad,\n                           tag=f"{a.candidate}__{arm}__s{seed}", ckpt_every_updates=100)\n')
r = subprocess.run([sys.executable, '-u', 'scripts/run_idea6_policy.py'] + ['--out', '/kaggle/working/idea6', '--wm-dir', 'output/experiments/2026-09-25_idea6/stageA', '--arms', 'wm_mlp', 'wm_hn_untrained', '--seeds', '0', '1', '--updates', '300', '--batch', '16', '--T', '250', '--d-model', '512'])
print('exit', r.returncode)
